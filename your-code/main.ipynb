# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are imported for you. If you prefer to use additional libraries feel free to uncomment them.

# %%
import requests as req
from bs4 import BeautifulSoup as bs
import pandas as pd
from IPython.display import HTML,Image
# from pprint import pprint
# from lxml import html
# from lxml.html import fromstring
# import urllib.request
# from urllib.request import urlopen
# import random
import re
# import scrapy

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

deve=req.get(url).text

sopa=bs(deve,'html.parser')

# %%
lst_developers=sopa.find('div', class_='position-relative container-lg p-responsive pt-6')

developers=lst_developers.find_all('h1',class_='h3 lh-condensed')

#developers.find('a').text.strip()
lst_dev=[]
for i in developers:
    lst_dev.append(i.find('a').text.strip())
    
lst_dev
# Out:
# ['Emil Ernerfeldt',
#  'Earle F. Philhower, III',
#  'Nikita Sobolev',
#  'Stephen Celis',
#  'Justin Fagnani',
#  'Manu MA',
#  'Joshua',
#  'Simon H',
#  'Marcus Olsson',
#  'Ben V. Brown',
#  'Jonny Borges',
#  'Andrew Kane',
#  'Wangchong Zhou',
#  'Mislav Marohnić',
#  'Matthias Fey',
#  'Elliana May',
#  'Romain Beaumont',
#  'Hari Sekhon',
#  'osy',
#  'Adam Johnson',
#  'Pedro Cuenca',
#  'Alex Gaynor',
#  'Henrik Rydgård',
#  'Joshua Levy',
#  'Mu Li']

# %%
lst_alias=sopa.find('div', class_='position-relative container-lg p-responsive pt-6')

alias=lst_alias.find_all('p',class_='f4 text-normal mb-1')
lst_alias=[]
for i in alias:
    lst_alias.append(i.find('a').text.strip())
    
lst_alias
# Out:
# ['emilk',
#  'earlephilhower',
#  'sobolevn',
#  'stephencelis',
#  'justinfagnani',
#  'manucorporat',
#  'minimalsm',
#  'dummdidumm',
#  'marcusolsson',
#  'Ralim',
#  'jonataslaw',
#  'ankane',
#  'fffonion',
#  'mislav',
#  'rusty1s',
#  'Mause',
#  'rom1504',
#  'HariSekhon',
#  'adamchainz',
#  'pcuenca',
#  'alex',
#  'hrydgard',
#  'jlevy',
#  'mli']

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
#ya lo había hecho arriba
data=[]
for dev, ali in zip(lst_dev,lst_alias):
    data.append(f'{dev} ({ali})')
    
data
# Out:
# ['Emil Ernerfeldt (emilk)',
#  'Earle F. Philhower, III (earlephilhower)',
#  'Nikita Sobolev (sobolevn)',
#  'Stephen Celis (stephencelis)',
#  'Justin Fagnani (justinfagnani)',
#  'Manu MA (manucorporat)',
#  'Joshua (minimalsm)',
#  'Simon H (dummdidumm)',
#  'Marcus Olsson (marcusolsson)',
#  'Ben V. Brown (Ralim)',
#  'Jonny Borges (jonataslaw)',
#  'Andrew Kane (ankane)',
#  'Wangchong Zhou (fffonion)',
#  'Mislav Marohnić (mislav)',
#  'Matthias Fey (rusty1s)',
#  'Elliana May (Mause)',
#  'Romain Beaumont (rom1504)',
#  'Hari Sekhon (HariSekhon)',
#  'osy (adamchainz)',
#  'Adam Johnson (pcuenca)',
#  'Pedro Cuenca (alex)',
#  'Alex Gaynor (hrydgard)',
#  'Henrik Rydgård (jlevy)',
#  'Joshua Levy (mli)']

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

html1=req.get(url).text

sopa=bs(html1,'html.parser')

# %%
lst_developers=sopa.find('div', class_='position-relative container-lg p-responsive pt-6')

developers=lst_developers.find_all('h1',class_='h3 lh-condensed')

#developers.find('a').text.strip()
lst_dev=[]
for i in developers:
    lst_dev.append(i.find('span', class_="text-normal").text.strip().replace('/','').replace(' ',''))
    
lst_dev
# Out:
# ['bregman-arie',
#  'public-apis',
#  'geohot',
#  'mlflow',
#  'PaddlePaddle',
#  'google',
#  'iterativv',
#  'netbox-community',
#  'tiangolo',
#  'streamlit',
#  'modelscope',
#  'LetusDevops',
#  'nerfstudio-project',
#  'idanya',
#  'heartexlabs',
#  'microsoft',
#  'sqlmapproject',
#  'unifyai',
#  'crytic',
#  'ultralytics',
#  'home-assistant',
#  'WeAreMahsaAmini',
#  'open-mmlab',
#  'Lightning-AI',
#  'demisto']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
html2=req.get(url).text

sopa=bs(html2,'html.parser')

imagenes=sopa.find_all('div', class_='thumbinner')

# %%
for i in imagenes:
    url=i.find('a').attrs['href']
    display(Image(url=url))
# Out:
# <img src="/wiki/File:Walt_Disney_Birthplace_Exterior_Hermosa_Chicago_Illinois.jpg"/>
# <img src="/wiki/File:Walt_Disney_envelope_ca._1921.jpg"/>
# <img src="/wiki/File:Newman_Laugh-O-Gram_(1921).webm"/>
# <img src="/wiki/File:Trolley_Troubles_poster.jpg"/>
# <img src="/wiki/File:Steamboat-willie.jpg"/>
# <img src="/wiki/File:Walt_Disney_1935.jpg"/>
# <img src="/wiki/File:Walt_Disney_Snow_white_1937_trailer_screenshot_(13).jpg"/>
# <img src="/wiki/File:Disney_drawing_goofy.jpg"/>
# <img src="/wiki/File:WaltDisneyplansDisneylandDec1954.jpg"/>
# <img src="/wiki/File:Walt_disney_portrait_right.jpg"/>
# <img src="/wiki/File:Walt_Disney_Grave.JPG"/>
# <img src="/wiki/File:Roy_O._Disney_with_Company_at_Press_Conference.jpg"/>
# <img src="/wiki/File:DisneySchiphol1951.jpg"/>
# <img src="/wiki/File:Disney1968.jpg"/>
# <img src="/wiki/File:Disney_Oscar_1953_(cropped).jpg"/>

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python' 

html3=req.get(url).text
sopa=bs(html3,'html.parser')

# %%
pagina=sopa.find_all('li')


lst_links=[]
for i in pagina:
    entrada=i.find('a').attrs['href']
    if 'wiki' in entrada:
        print(entrada)

# %% [markdown]
# #### Number of Titles that have changed in the United States Code since its last release point

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
html4=req.get(url).text

sopa=bs(html4,'html.parser')

paso=sopa.find_all('div', class_='usctitlechanged')

paso

# %%
numero=0
for i in paso:
    numero+=1
    
print("los elementos modificados son: ",numero)
# Out:
# los elementos modificados son:  9

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

html5=req.get(url).text

sopa=bs(html5,'html.parser')

#fugitivos=sopa.find_all('ul',class_='full-grid wanted-grid-natural infinity castle-grid-block-xs-2 castle-grid-block-sm-2castle-grid-block-md-3 castle-grid-block-lg-5 dt-grid' )

# %%
fugitivo=sopa.find_all('li', class_='portal-type-person castle-grid-block-item')

lst_fug=[]
for i in fugitivo:
    lst_fug.append(i.find('h3').text.replace('\n',''))
    
lst_fug
# Out:
# ['OMAR ALEXANDER CARDENAS',
#  'ALEXIS FLORES',
#  'JOSE RODOLFO VILLARREAL-HERNANDEZ',
#  'YULAN ADONAY ARCHAGA CARIAS',
#  'BHADRESHKUMAR CHETANBHAI PATEL',
#  'ALEJANDRO ROSALES CASTILLO',
#  'MICHAEL JAMES PRATT',
#  'RUJA IGNATOVA',
#  'ARNOLDO JIMENEZ',
#  'RAFAEL CARO-QUINTERO']

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

html6=req.get(url).text
sopa6=bs(html6,'html.parser')

quake=sopa6.find('tbody',id='tbody')

# %%
date_time=quake.find_all('td',class_='tabev6')
latitud_longituf=quake.find_all('td',class_='tabev1')
dir_lat_log=quake.find_all('td',class_='tabev2')
region=quake.find_all('td',class_='tb_region')

regiones=[]
for i in region:
    regiones.append(i.text.replace('\xa0',''))
regiones
# Out:
# ['CENTRAL CALIFORNIA',
#  'NEPAL-INDIA BORDER REGION',
#  'CANARY ISLANDS, SPAIN REGION',
#  'PANAMA',
#  'PUERTO RICO',
#  'SLOVENIA',
#  'SWITZERLAND',
#  'SALTA, ARGENTINA',
#  'NORTHERN CALIFORNIA',
#  'LIGURIAN SEA',
#  'NEPAL',
#  'PUERTO RICO',
#  'HAWAII REGION, HAWAII',
#  'SERAM, INDONESIA',
#  'ANTOFAGASTA, CHILE',
#  'SPAIN',
#  'ANDREANOF ISLANDS, ALEUTIAN IS.',
#  'LUZON, PHILIPPINES',
#  'OFFSHORE MAULE, CHILE',
#  'OFF COAST OF COSTA RICA',
#  'SULAWESI, INDONESIA',
#  'NEVADA',
#  'OFFSHORE MAULE, CHILE',
#  'COQUIMBO, CHILE',
#  'NEVADA',
#  'ISLAND OF HAWAII, HAWAII',
#  'SOUTHERN SUMATRA, INDONESIA',
#  'SAN JUAN, ARGENTINA',
#  'WESTERN TEXAS',
#  'NEAR COAST OF NICARAGUA',
#  'SALTA, ARGENTINA',
#  'PUERTO RICO REGION',
#  'CUBA REGION',
#  'VALPARAISO, CHILE',
#  'SALTA, ARGENTINA',
#  'PHILIPPINE ISLANDS REGION',
#  'SICILY, ITALY',
#  'MOLUCCA SEA',
#  'SAMAR, PHILIPPINES',
#  'PUERTO RICO',
#  'GULF OF CALIFORNIA',
#  'OAXACA, MEXICO',
# ...

# %%
lst_datetime=[]
lst_date=[]
lst_time=[]

for i in date_time:
    lst_datetime.append(i.text)
    
for i in lst_datetime:
    
    date=re.findall('\d+\-\d+\-\d+',i)
    time=re.findall('\d+\:\d+\:\d+',i)
    
    lst_date.append(date[0])
    lst_time.append(time[0])

# %%
lst_latitud_longituf=[]
lst_latitud=[]
lst_longitud=[]
latitud_longituf
for i in latitud_longituf:
    lst_latitud_longituf.append(i.text.replace('\xa0',''))
    
for i in range(len(lst_latitud_longituf)):
    if i%2==0:
        lst_latitud.append(lst_latitud_longituf[i])
    else:
        lst_longitud.append(lst_latitud_longituf[i])
        
lst_dir_lat_log=[]
lst_dir_lat=[]
lst_dir_log=[]

for i in dir_lat_log:
    lst_dir_lat_log.append(i.text.replace('\xa0',''))
    
    
for i in range(1,len(lst_dir_lat_log)):
    
    if i%3==0:
        
        pass
    elif i%2==0:
        
        lst_dir_lat.append(lst_dir_lat_log[i-1])
    else:
        
        lst_dir_log.append(lst_dir_lat_log[i-1])
        
lst_lati=[]
lst_long=[]

for lat, dir in zip(lst_latitud,lst_dir_lat):
    lst_lati.append(f'{lat} {dir}')
    
for log, dir in zip(lst_longitud,lst_dir_log):
    lst_long.append(f'{lat} {dir}')
    
dictquake=[]
for date,time,lat,log,area in zip(lst_date,lst_time,lst_lati,lst_long,regiones):
    dictquake.append({'date': date,
                         'time': time,
                         'latitud': lat,
                         'longitud': log,
                         'area': area})
    
df=pd.DataFrame(dictquake)

df.head()
# Out:
#          date      time  latitud longitud                          area
# 0  2022-11-08  16:19:42  36.00 W  31.55 N            CENTRAL CALIFORNIA
# 1  2022-11-08  16:11:35  29.62 N  31.55 E     NEPAL-INDIA BORDER REGION
# 2  2022-11-08  16:04:03  28.61 W  31.55 N  CANARY ISLANDS, SPAIN REGION
# 3  2022-11-08  16:00:22   9.49 N  31.55 W                        PANAMA
# 4  2022-11-08  15:49:16  18.03 W  31.55 N                   PUERTO RICO

# %% [markdown]
# #### Display the date, days, title, city, country of next 25 hackathon events as a Pandas dataframe table

# %%
# This is the url you will scrape in this exercise
url ='https://hackevents.co/hackathons'

# %%
#your code

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/kilianj'

html7=req.get(url).text

sopa7=bs(html7,'html.parser')

# %%
tweets=sopa7.find_all('div',class_='css-1dbjc4n')

# %%
#your code

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

html8=req.get(url).text
sopa8=bs(html8,'html.parser')
lst_idiomas=('es','en','ja', 'ru','fr','de','it','zh','pt','ar')
sopa8

# %%
lst_idiomas=[]

for i in range(1,8):
    idiomas=sopa8.find('div', class_=f'central-featured-lang lang{i}')
    print(idiomas.text)
    lst_idiomas.append(idiomas.text.replace('\n',''))


lst_idiomas
# Out:
# English
# 6 458 000+ articles
#
#
#
#
# æ¥æ¬èª
# 1 314 000+ è¨äº
#
#
#
#
# EspaÃ±ol
# 1 755 000+ artÃ­culos
#
#
#
#
# Ð ÑÑÑÐºÐ¸Ð¹
# 1 798 000+ ÑÑÐ°ÑÐµÐ¹
#
#
#
#
# FranÃ§ais
# 2 400 000+ articles
#
#
#
#
# Deutsch
# 2 667 000+ Artikel
#
#
#
#
# Italiano
# 1 742 000+ voci
# ['English6\xa0458\xa0000+ articles',
#  'æ\x97¥æ\x9c¬èª\x9e1\xa0314\xa0000+ è¨\x98äº\x8b',
#  'EspaÃ±ol1\xa0755\xa0000+ artÃ\xadculos',
#  'Ð\xa0Ñ\x83Ñ\x81Ñ\x81ÐºÐ¸Ð¹1\xa0798\xa0000+ Ñ\x81Ñ\x82Ð°Ñ\x82ÐµÐ¹',
#  'FranÃ§ais2\xa0400\xa0000+ articles',
#  'Deutsch2\xa0667\xa0000+ Artikel',
#  'Italiano1\xa0742\xa0000+ voci']

# %%
#your code

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

html9=req.get(url).text

sopa9=bs(html9,'html.parser')

# %%
categorias=sopa9.find_all('h3', class_='govuk-heading-s dgu-topics__heading')
lst_categorias=[]
for i in categorias:
    lst_categorias.append(i.text)
lst_categorias
# Out:
# ['Business and economy',
#  'Crime and justice',
#  'Defence',
#  'Education',
#  'Environment',
#  'Government',
#  'Government spending',
#  'Health',
#  'Mapping',
#  'Society',
#  'Towns and cities',
#  'Transport',
#  'Digital service performance',
#  'Government reference data']

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

html10=req.get(url).text
sopa10=bs(html10, 'html.parser')

# %%
tablas=sopa10.find('table')

p=tablas.find_all('tr')

lst=[]
for i in p:
    l=i.text.split('\n')
    lst.append(l)


df3=pd.DataFrame(lst)

df4=df3.drop(index=0)

df4.iloc[0:10]
# Out:
#    0                                                  1 2     3 4  \
# 1     Mandarin Chinese(incl. Standard Chinese, but e...     920
# 2                                               Spanish     475
# 3                                               English     373
# 4                                     Hindi(excl. Urdu)     344
# 5                                               Bengali     234
# 6                                            Portuguese     232
# 7                                               Russian     154
# 8                                              Japanese     125
# 9                          Yue Chinese(incl. Cantonese)    85.2
# 10                                           Vietnamese    84.6
#
#                 5 6             7 8
# 1    Sino-Tibetan         Sinitic
# 2   Indo-European         Romance
# 3   Indo-European        Germanic
# 4   Indo-European      Indo-Aryan
# 5   Indo-European      Indo-Aryan
# 6   Indo-European         Romance
# ...

# %% [markdown]
# ### BONUS QUESTIONS

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

html11=req.get(url).text

sopa11=bs(html11,'html.parser')

sopa11
# Out:
# <!DOCTYPE html>
#
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>Top 250 Movies - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "LoadTitle", {wb: 1});
#     }
# </script>
# <link href="https://www.imdb.com/chart/top" rel="canonical"/>
# <meta content="http://www.imdb.com/chart/top" property="og:url">
# <script>
# ...

# %%
titulo=sopa11.find_all('td', class_='titleColumn')

directores=[]
titulos=[]
for i in titulo:
    directores.append(i.find('a').attrs['title'])
    titulos.append(i.text.replace('\n','').strip())
    
directores_buenos=[]

for i in directores:
    palabra=re.findall('\D+\(dir.\)',i)
    directores_buenos.append(palabra)
directores_buenos
titulos

# %%
stars=sopa11.find_all('td', class_='ratingColumn imdbRating')

star=[]
for i in stars:
    star.append(i.text.replace('\n',''))
    
star

final=[]
for n,d,s in zip(titulos,directores_buenos,star):
    final.append({'titulos':n,
                  'directores':d,
                  'estrellas':s
})
    
df=pd.DataFrame(final)
    
df

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'
html12=req.get(url).text
sopa11=bs(html12,'html.parser')

# %%
titulo=sopa11.find_all('td', class_='titleColumn')

directores=[]
titulos=[]
links=[]

numero=0
for i in titulo:
    if numero<10:
        directores.append(i.find('a').attrs['title'])
        titulos.append(i.text.replace('\n','').strip())
        links.append(i.find('a').attrs['href'])
        numero+=1
    else:
        break
# Out:
# 10

# %%
titulis=[]
fechas=[]
for i in titulos:
    palabra1=re.findall('[a-zA-Z]+\D+[a-zA-Z]+\)',i)
    palabra2=re.findall('[a-zA-Z]+\D+[a-zA-Z]+',i)
    fecha=re.findall('\(+\d+\)',i)
    if re.findall('[a-zA-Z]+\D+[a-zA-Z]+\)',i):
        titulis.append("".join(palabra1))
    elif re.findall('[a-zA-Z]+\D+[a-zA-Z]+',i):
        titulis.append("".join(palabra2))
    if re.findall('\(+\d+\)',i):
        fechas.append("".join(fecha))
        
titulis
# Out:
# ['Cadena perpetua',
#  'El padrino',
#  'El caballero oscuro',
#  'El padrino (parte II)',
#  'hombres sin piedad',
#  'La lista de Schindler',
#  'El señor de los anillos: El retorno del rey',
#  'Pulp Fiction',
#  'El señor de los anillos: La comunidad del anillo',
#  'El bueno, el feo y el malo']

# %%
descrip=[]

for i in links:
    
    url_links='https://www.imdb.com' + i + '?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=1a264172-ae11-42e4-8ef7-7fed1973bb8f&pf_rd_r=Y9KNFBSYDHDT9A5P5Q5S&pf_rd_s=center-1&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_tt_1'
     
    
    con=req.get(url_links).text
    
    soap=bs(con,'html.parser')
    drama=soap.find('span', class_='sc-16ede01-0 fMPjMP').text
    descrip.append(drama)

# %%
data_final=[]
for n,y,d in zip(titulis,fechas,descrip):
    data_final.append({'titulo':n,
                       'annio':y,
                       'descripcion':d
        
    })
    
df_imd=pd.DataFrame(data_final)

df_imd
# Out:
#                                              titulo   annio  \
# 0                                   Cadena perpetua  (1994)
# 1                                        El padrino  (1972)
# 2                               El caballero oscuro  (2008)
# 3                             El padrino (parte II)  (1974)
# 4                                hombres sin piedad  (1957)
# 5                             La lista de Schindler  (1993)
# 6       El señor de los anillos: El retorno del rey  (2003)
# 7                                      Pulp Fiction  (1994)
# 8  El señor de los anillos: La comunidad del anillo  (2001)
# 9                        El bueno, el feo y el malo  (1966)
#
#                                          descripcion
# 0  Two imprisoned men bond over a number of years...
# 1  The aging patriarch of an organized crime dyna...
# 2  When the menace known as the Joker wreaks havo...
# 3  The early life and career of Vito Corleone in ...
# ...

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?q='+city+'&appid=c5ba0d0d8410dea7ea53ce7f12a6e4af&units=metric'


eltiempo=req.get(url)

# %%
eltiempo.json()
# Out:
# {'cod': 401,
#  'message': 'Invalid API key. Please see https://openweathermap.org/faq#error401 for more info.'}

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

libros=req.get(url).text

sop_lib=bs(libros,'html.parser')

libreria=sop_lib.find_all('article', class_='product_pod')

# %%
lst_libros=[]
for i in libreria:
    nombre=i.find('img').attrs['alt']
    precio=i.find('p',class_='price_color').text.replace('Â','')
    stock=i.find('p',class_='instock availability').text.replace('\n','').strip()
    lst_libros.append({'titulo':nombre,
                       'precio':precio,
                       'stock':stock

    })
    
df_libros=pd.DataFrame(lst_libros)
df_libros
# Out:
#                                                titulo  precio     stock
# 0                                A Light in the Attic  £51.77  In stock
# 1                                  Tipping the Velvet  £53.74  In stock
# 2                                          Soumission  £50.10  In stock
# 3                                       Sharp Objects  £47.82  In stock
# 4               Sapiens: A Brief History of Humankind  £54.23  In stock
# 5                                     The Requiem Red  £22.65  In stock
# 6   The Dirty Little Secrets of Getting Your Dream...  £33.34  In stock
# 7   The Coming Woman: A Novel Based on the Life of...  £17.93  In stock
# 8   The Boys in the Boat: Nine Americans and Their...  £22.60  In stock
# 9                                     The Black Maria  £52.15  In stock
# 10     Starving Hearts (Triangular Trade Trilogy, #1)  £13.99  In stock
# 11                              Shakespeare's Sonnets  £20.66  In stock
# ...
