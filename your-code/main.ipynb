# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are imported for you. If you prefer to use additional libraries feel free to uncomment them.

# %%
import requests as req
from bs4 import BeautifulSoup as bs
import pandas as pd
import re
from IPython.display import Image
import unicodedata

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

html=req.get(url).text
soup=bs(html, 'html.parser')
# Out:
# From cffi callback <function _verify_callback at 0x0000016554075048>:
# Traceback (most recent call last):
#   File "C:\Users\david\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 306, in wrapper
#     @wraps(callback)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     455             try:
# --> 456                 cnx.do_handshake()
#     457             except OpenSSL.SSL.WantReadError:
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1914         result = _lib.SSL_do_handshake(self._ssl)
# -> 1915         self._raise_ssl_error(self._ssl, result)
#    1916
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1646         else:
# -> 1647             _raise_current_error()
#    1648
#
# ~\Anaconda3\lib\site-packages\OpenSSL\_util.py in exception_from_error_queue(exception_type)
#      53
# ---> 54     raise exception_type(errors)
#      55
#
# Error: [('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')]
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     343             server_hostname=server_hostname,
# --> 344             ssl_context=context)
#     345
#
# ~\Anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     346         if HAS_SNI and server_hostname is not None:
# --> 347             return context.wrap_socket(sock, server_hostname=server_hostname)
#     348
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     461             except OpenSSL.SSL.Error as e:
# --> 462                 raise ssl.SSLError('bad handshake: %r' % e)
#     463             break
#
# SSLError: ("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])",)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#
# MaxRetryError: HTTPSConnectionPool(host='github.com', port=443): Max retries exceeded with url: /trending/developers (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-2-0ffee915d4c5> in <module>
#       2 url = 'https://github.com/trending/developers'
#       3
# ----> 4 html=req.get(url).text
#       5 soup=bs(html, 'html.parser')
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     512             if isinstance(e.reason, _SSLError):
#     513                 # This branch is for urllib3 v1.22 and later.
# --> 514                 raise SSLError(e, request=request)
#     515
#     516             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='github.com', port=443): Max retries exceeded with url: /trending/developers (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
for e in soup.find_all('h1', class_='h3 lh-condensed'):
    print (e.text.strip())

# %%
#[e.text.strip() for e in soup.find_all('h1', class_='h3 lh-condensed')]

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
html=req.get(url).text
soup=bs(html, 'html.parser')

# %%
nombres=[]
for e in soup.find_all('a', class_='h3 lh-condensed'):
        nombres.append(e.text.strip().replace(',', '').replace('\n', ''). replace('/',''))
            

nombres

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'
html=req.get(url).text
soup=bs(html, 'html.parser')

# %%
#imagenes=[]
#images=soup.find_all('img', {'src':re.compile('.jpg')})
#for image in images: 
#    imagenes.append(image['src']+'\n')
#    
#for i in imagenes:
#    display(Image(url=i))

# %%
imagenes=[]
images=soup.find_all('img')
for image in images: 
    display(Image(url=image.attrs['src']))

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python' 
html=req.get(url).text
soup=bs(html, 'html.parser')

link=soup.find_all('link')

# %%
for e in link:
    print (e.attrs['href'])

# %% [markdown]
# #### Number of Titles that have changed in the United States Code since its last release point

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
html=req.get(url).text
soup=bs(html, 'html.parser')
libros=soup.find_all('div', class_='usctitlechanged')
libros

for l in libros:
    print (l.text.strip())

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

html=req.get(url).text
soup=bs(html, 'html.parser')

# %%
for e in soup.find_all('h3', class_='title'):
    print (e.text.strip())

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

html=req.get(url).text
soup=bs(html, 'html.parser')

# %%
#your code
for e in soup.find_all('tbody'):
    fecha=e.find('b').text.replace('earthquake', '')
    long=e.find(class_='tabev1').text
    long2=e.find(class_='tabev2').text
    lat=e.find(class_='tabev3').text
    lat2=e.find(class_='tabev4').text
    print(lat)

# %% [markdown]
# #### Display the date, days, title, city, country of next 25 hackathon events as a Pandas dataframe table

# %%
# This is the url you will scrape in this exercise
url ='https://hackevents.co/hackathons'

html=req.get(url).text
soup=bs(html, 'html.parser')

# %%
#your code

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

html=req.get(url).text
soup=bs(html, 'html.parser')

# %%
#your code

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

html=req.get(url).text
soup=bs(html, 'html.parser')

# %%
#your code
idiomas=soup.find_all('div', class_='central-featured')

# %%
lista=[]
for e in idiomas:
    lan = e.find_all('strong')
    for n in lan:
        lista.append(n.text)
lista
# Out:
# ['English',
#  'æ\x97¥æ\x9c¬èª\x9e',
#  'EspaÃ±ol',
#  'Ð\xa0Ñ\x83Ñ\x81Ñ\x81ÐºÐ¸Ð¹',
#  'FranÃ§ais',
#  'Deutsch',
#  'Italiano',
#  'ä¸\xadæ\x96\x87',
#  'PortuguÃªs',
#  'Ø§Ù\x84Ø¹Ø±Ø¨Ù\x8aØ©']

# %%
lista2=[]
for e in idiomas:
    num = e.find_all('bdi')
    for a in num:
        string=a.text.replace('\xa0','').replace('+',' ')
        
        lista2.append(string)
lista2
# Out:
# ['6458000 ',
#  '1314000 ',
#  '1755000 ',
#  '1798000 ',
#  '2400000 ',
#  '2667000 ',
#  '1742000 ',
#  '1256000 ',
#  '1085000 ',
#  'Ø§Ù\x84Ø¹Ø±Ø¨Ù\x8aØ©',
#  '1159000 ']

# %%
["{}{}".format(b_, a_) for a_, b_ in zip(lista, lista2)]
# Out:
# ['6458000 English',
#  '1314000 æ\x97¥æ\x9c¬èª\x9e',
#  '1755000 EspaÃ±ol',
#  '1798000 Ð\xa0Ñ\x83Ñ\x81Ñ\x81ÐºÐ¸Ð¹',
#  '2400000 FranÃ§ais',
#  '2667000 Deutsch',
#  '1742000 Italiano',
#  '1256000 ä¸\xadæ\x96\x87',
#  '1085000 PortuguÃªs',
#  'Ø§Ù\x84Ø¹Ø±Ø¨Ù\x8aØ©Ø§Ù\x84Ø¹Ø±Ø¨Ù\x8aØ©']

# %%
aux=[]
for e in soup.find_all('div', class_='central-featured'):
    
    aux.append(e.text.strip())

aux
# Out:
# ['English\n6\xa0458\xa0000+ articles\n\n\n\n\n\næ\x97¥æ\x9c¬èª\x9e\n1\xa0314\xa0000+ è¨\x98äº\x8b\n\n\n\n\n\nEspaÃ±ol\n1\xa0755\xa0000+ artÃ\xadculos\n\n\n\n\n\nÐ\xa0Ñ\x83Ñ\x81Ñ\x81ÐºÐ¸Ð¹\n1\xa0798\xa0000+ Ñ\x81Ñ\x82Ð°Ñ\x82ÐµÐ¹\n\n\n\n\n\nFranÃ§ais\n2\xa0400\xa0000+ articles\n\n\n\n\n\nDeutsch\n2\xa0667\xa0000+ Artikel\n\n\n\n\n\nItaliano\n1\xa0742\xa0000+ voci\n\n\n\n\n\nä¸\xadæ\x96\x87\n1\xa0256\xa0000+ æ\x9d¡ç\x9b® / æ¢\x9dç\x9b®\n\n\n\n\n\nPortuguÃªs\n1\xa0085\xa0000+ artigos\n\n\n\n\n\nØ§Ù\x84Ø¹Ø±Ø¨Ù\x8aØ©\n1\xa0159\xa0000+ Ù\x85Ù\x82Ø§Ù\x84Ø©']

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'
html=req.get(url).text
soup=bs(html, 'html.parser')

# %%
#your code 
[e.text.strip() for e in soup.find_all('h3', class_='govuk-heading-s dgu-topics__heading')]
# Out:
# ['Business and economy',
#  'Crime and justice',
#  'Defence',
#  'Education',
#  'Environment',
#  'Government',
#  'Government spending',
#  'Health',
#  'Mapping',
#  'Society',
#  'Towns and cities',
#  'Transport',
#  'Digital service performance',
#  'Government reference data']

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

html=req.get(url).text
soup=bs(html, 'html.parser')

# %%
tabla=soup.find_all('table')[0]

# %%
tabla.find_all('tr')[0].text.split('\n')
# Out:
# ['',
#  'Language',
#  '',
#  'Native speakers(millions)',
#  '',
#  'Language family',
#  '',
#  'Branch',
#  '']

# %%
filas=tabla.find_all('tr')

filas=[f.text.strip().split('\n') for f in filas]

# %%
filas=[[palabra for palabra in f if palabra!=''] for f in filas]

# %%
import pandas as pd

col_names=filas[0]

data=filas[1:]

df=pd.DataFrame(data, columns=col_names)

# %%
df.sort_values(by=['Native speakers(millions)']).head(10)
# Out:
#                                  Language Native speakers(millions)  \
# 7                                Japanese                       125
# 6                                 Russian                       154
# 5                              Portuguese                       232
# 4                                 Bengali                       234
# 3                       Hindi(excl. Urdu)                       344
# 2                                 English                       373
# 1                                 Spanish                       475
# 26                                  Hausa                      50.8
# 25                               Bhojpuri                      52.3
# 24  Iranian Persian(excl. Dari and Tajik)                      56.4
#
#    Language family        Branch
# 7          Japonic      Japanese
# 6    Indo-European  Balto-Slavic
# 5    Indo-European       Romance
# 4    Indo-European    Indo-Aryan
# 3    Indo-European    Indo-Aryan
# 2    Indo-European      Germanic
# 1    Indo-European       Romance
# 26     Afroasiatic        Chadic
# 25   Indo-European    Indo-Aryan
# 24   Indo-European       Iranian

# %% [markdown]
# ### BONUS QUESTIONS

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

html=req.get(url).text
soup=bs(html, 'html.parser')

# %%
for e in soup.find_all('td'):
    print(e.find(''))
# Out:
# <span data-value="1" name="rk"></span>
# <a href="/title/tt0111161/" title="Frank Darabont (dir.), Tim Robbins, Morgan Freeman">Cadena perpetua</a>
# <strong title="9.2 based on 2,659,028 user ratings">9.2</strong>
# <div class="seen-widget seen-widget-tt0111161 pending" data-titleid="tt0111161">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0111161"></div>
# <span data-value="2" name="rk"></span>
# <a href="/title/tt0068646/" title="Francis Ford Coppola (dir.), Marlon Brando, Al Pacino">El padrino</a>
# <strong title="9.2 based on 1,842,758 user ratings">9.2</strong>
# <div class="seen-widget seen-widget-tt0068646 pending" data-titleid="tt0068646">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0068646"></div>
# <span data-value="3" name="rk"></span>
# <a href="/title/tt0468569/" title="Christopher Nolan (dir.), Christian Bale, Heath Ledger">El caballero oscuro</a>
# <strong title="9.0 based on 2,631,832 user ratings">9.0</strong>
# <div class="seen-widget seen-widget-tt0468569 pending" data-titleid="tt0468569">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0468569"></div>
# <span data-value="4" name="rk"></span>
# <a href="/title/tt0071562/" title="Francis Ford Coppola (dir.), Al Pacino, Robert De Niro">El padrino (parte II)</a>
# <strong title="9.0 based on 1,262,461 user ratings">9.0</strong>
# <div class="seen-widget seen-widget-tt0071562 pending" data-titleid="tt0071562">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0071562"></div>
# <span data-value="5" name="rk"></span>
# <a href="/title/tt0050083/" title="Sidney Lumet (dir.), Henry Fonda, Lee J. Cobb">12 hombres sin piedad</a>
# <strong title="9.0 based on 785,099 user ratings">9.0</strong>
# <div class="seen-widget seen-widget-tt0050083 pending" data-titleid="tt0050083">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0050083"></div>
# <span data-value="6" name="rk"></span>
# <a href="/title/tt0108052/" title="Steven Spielberg (dir.), Liam Neeson, Ralph Fiennes">La lista de Schindler</a>
# <strong title="8.9 based on 1,346,811 user ratings">8.9</strong>
# <div class="seen-widget seen-widget-tt0108052 pending" data-titleid="tt0108052">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0108052"></div>
# <span data-value="7" name="rk"></span>
# <a href="/title/tt0167260/" title="Peter Jackson (dir.), Elijah Wood, Viggo Mortensen">El señor de los anillos: El retorno del rey</a>
# <strong title="8.9 based on 1,833,447 user ratings">8.9</strong>
# <div class="seen-widget seen-widget-tt0167260 pending" data-titleid="tt0167260">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0167260"></div>
# <span data-value="8" name="rk"></span>
# <a href="/title/tt0110912/" title="Quentin Tarantino (dir.), John Travolta, Uma Thurman">Pulp Fiction</a>
# <strong title="8.8 based on 2,035,180 user ratings">8.8</strong>
# <div class="seen-widget seen-widget-tt0110912 pending" data-titleid="tt0110912">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0110912"></div>
# <span data-value="9" name="rk"></span>
# <a href="/title/tt0120737/" title="Peter Jackson (dir.), Elijah Wood, Ian McKellen">El señor de los anillos: La comunidad del anillo</a>
# <strong title="8.8 based on 1,862,235 user ratings">8.8</strong>
# <div class="seen-widget seen-widget-tt0120737 pending" data-titleid="tt0120737">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0120737"></div>
# <span data-value="10" name="rk"></span>
# <a href="/title/tt0060196/" title="Sergio Leone (dir.), Clint Eastwood, Eli Wallach">El bueno, el feo y el malo</a>
# <strong title="8.8 based on 758,085 user ratings">8.8</strong>
# <div class="seen-widget seen-widget-tt0060196 pending" data-titleid="tt0060196">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0060196"></div>
# <span data-value="11" name="rk"></span>
# <a href="/title/tt0109830/" title="Robert Zemeckis (dir.), Tom Hanks, Robin Wright">Forrest Gump</a>
# <strong title="8.8 based on 2,060,254 user ratings">8.8</strong>
# <div class="seen-widget seen-widget-tt0109830 pending" data-titleid="tt0109830">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0109830"></div>
# <span data-value="12" name="rk"></span>
# <a href="/title/tt0137523/" title="David Fincher (dir.), Brad Pitt, Edward Norton">El club de la lucha</a>
# <strong title="8.7 based on 2,104,153 user ratings">8.7</strong>
# <div class="seen-widget seen-widget-tt0137523 pending" data-titleid="tt0137523">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0137523"></div>
# <span data-value="13" name="rk"></span>
# <a href="/title/tt0167261/" title="Peter Jackson (dir.), Elijah Wood, Ian McKellen">El señor de los anillos: Las dos torres</a>
# <strong title="8.7 based on 1,655,534 user ratings">8.7</strong>
# <div class="seen-widget seen-widget-tt0167261 pending" data-titleid="tt0167261">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0167261"></div>
# <span data-value="14" name="rk"></span>
# <a href="/title/tt1375666/" title="Christopher Nolan (dir.), Leonardo DiCaprio, Joseph Gordon-Levitt">Origen</a>
# <strong title="8.7 based on 2,332,114 user ratings">8.7</strong>
# <div class="seen-widget seen-widget-tt1375666 pending" data-titleid="tt1375666">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt1375666"></div>
# <span data-value="15" name="rk"></span>
# <a href="/title/tt0080684/" title="Irvin Kershner (dir.), Mark Hamill, Harrison Ford">El Imperio contraataca</a>
# <strong title="8.7 based on 1,284,349 user ratings">8.7</strong>
# <div class="seen-widget seen-widget-tt0080684 pending" data-titleid="tt0080684">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0080684"></div>
# <span data-value="16" name="rk"></span>
# <a href="/title/tt0133093/" title="Lana Wachowski (dir.), Keanu Reeves, Laurence Fishburne">Matrix</a>
# <strong title="8.7 based on 1,900,344 user ratings">8.7</strong>
# <div class="seen-widget seen-widget-tt0133093 pending" data-titleid="tt0133093">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0133093"></div>
# <span data-value="17" name="rk"></span>
# <a href="/title/tt0099685/" title="Martin Scorsese (dir.), Robert De Niro, Ray Liotta">Uno de los nuestros</a>
# <strong title="8.7 based on 1,152,109 user ratings">8.7</strong>
# <div class="seen-widget seen-widget-tt0099685 pending" data-titleid="tt0099685">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0099685"></div>
# <span data-value="18" name="rk"></span>
# <a href="/title/tt0073486/" title="Milos Forman (dir.), Jack Nicholson, Louise Fletcher">Alguien voló sobre el nido del cuco</a>
# <strong title="8.6 based on 1,003,190 user ratings">8.6</strong>
# <div class="seen-widget seen-widget-tt0073486 pending" data-titleid="tt0073486">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0073486"></div>
# <span data-value="19" name="rk"></span>
# <a href="/title/tt0114369/" title="David Fincher (dir.), Morgan Freeman, Brad Pitt">Seven</a>
# <strong title="8.6 based on 1,638,427 user ratings">8.6</strong>
# <div class="seen-widget seen-widget-tt0114369 pending" data-titleid="tt0114369">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0114369"></div>
# <span data-value="20" name="rk"></span>
# <a href="/title/tt0047478/" title="Akira Kurosawa (dir.), Toshirô Mifune, Takashi Shimura">Los siete samuráis</a>
# <strong title="8.6 based on 345,270 user ratings">8.6</strong>
# <div class="seen-widget seen-widget-tt0047478 pending" data-titleid="tt0047478">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0047478"></div>
# <span data-value="21" name="rk"></span>
# <a href="/title/tt0038650/" title="Frank Capra (dir.), James Stewart, Donna Reed">¡Qué bello es vivir!</a>
# <strong title="8.6 based on 453,738 user ratings">8.6</strong>
# <div class="seen-widget seen-widget-tt0038650 pending" data-titleid="tt0038650">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0038650"></div>
# <span data-value="22" name="rk"></span>
# <a href="/title/tt0102926/" title="Jonathan Demme (dir.), Jodie Foster, Anthony Hopkins">El silencio de los corderos</a>
# <strong title="8.6 based on 1,422,470 user ratings">8.6</strong>
# <div class="seen-widget seen-widget-tt0102926 pending" data-titleid="tt0102926">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0102926"></div>
# <span data-value="23" name="rk"></span>
# <a href="/title/tt0317248/" title="Fernando Meirelles (dir.), Alexandre Rodrigues, Leandro Firmino">Ciudad de Dios</a>
# <strong title="8.6 based on 753,929 user ratings">8.6</strong>
# <div class="seen-widget seen-widget-tt0317248 pending" data-titleid="tt0317248">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0317248"></div>
# <span data-value="24" name="rk"></span>
# <a href="/title/tt0120815/" title="Steven Spielberg (dir.), Tom Hanks, Matt Damon">Salvar al soldado Ryan</a>
# <strong title="8.6 based on 1,381,950 user ratings">8.6</strong>
# <div class="seen-widget seen-widget-tt0120815 pending" data-titleid="tt0120815">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0120815"></div>
# <span data-value="25" name="rk"></span>
# <a href="/title/tt0118799/" title="Roberto Benigni (dir.), Roberto Benigni, Nicoletta Braschi">La vida es bella</a>
# <strong title="8.6 based on 691,415 user ratings">8.6</strong>
# <div class="seen-widget seen-widget-tt0118799 pending" data-titleid="tt0118799">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0118799"></div>
# <span data-value="26" name="rk"></span>
# <a href="/title/tt0816692/" title="Christopher Nolan (dir.), Matthew McConaughey, Anne Hathaway">Interstellar</a>
# <strong title="8.6 based on 1,804,447 user ratings">8.6</strong>
# <div class="seen-widget seen-widget-tt0816692 pending" data-titleid="tt0816692">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0816692"></div>
# <span data-value="27" name="rk"></span>
# <a href="/title/tt0120689/" title="Frank Darabont (dir.), Tom Hanks, Michael Clarke Duncan">La milla verde</a>
# <strong title="8.6 based on 1,292,004 user ratings">8.6</strong>
# <div class="seen-widget seen-widget-tt0120689 pending" data-titleid="tt0120689">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0120689"></div>
# <span data-value="28" name="rk"></span>
# <a href="/title/tt0076759/" title="George Lucas (dir.), Mark Hamill, Harrison Ford">La guerra de las galaxias</a>
# <strong title="8.6 based on 1,356,984 user ratings">8.6</strong>
# <div class="seen-widget seen-widget-tt0076759 pending" data-titleid="tt0076759">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0076759"></div>
# <span data-value="29" name="rk"></span>
# <a href="/title/tt0103064/" title="James Cameron (dir.), Arnold Schwarzenegger, Linda Hamilton">Terminator 2: El juicio final</a>
# <strong title="8.5 based on 1,092,855 user ratings">8.5</strong>
# <div class="seen-widget seen-widget-tt0103064 pending" data-titleid="tt0103064">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0103064"></div>
# <span data-value="30" name="rk"></span>
# <a href="/title/tt0088763/" title="Robert Zemeckis (dir.), Michael J. Fox, Christopher Lloyd">Regreso al futuro</a>
# <strong title="8.5 based on 1,195,591 user ratings">8.5</strong>
# <div class="seen-widget seen-widget-tt0088763 pending" data-titleid="tt0088763">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0088763"></div>
# <span data-value="31" name="rk"></span>
# <a href="/title/tt0245429/" title="Hayao Miyazaki (dir.), Daveigh Chase, Suzanne Pleshette">El viaje de Chihiro</a>
# <strong title="8.5 based on 757,152 user ratings">8.5</strong>
# <div class="seen-widget seen-widget-tt0245429 pending" data-titleid="tt0245429">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0245429"></div>
# <span data-value="32" name="rk"></span>
# <a href="/title/tt0054215/" title="Alfred Hitchcock (dir.), Anthony Perkins, Janet Leigh">Psicosis</a>
# <strong title="8.5 based on 669,270 user ratings">8.5</strong>
# <div class="seen-widget seen-widget-tt0054215 pending" data-titleid="tt0054215">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0054215"></div>
# <span data-value="33" name="rk"></span>
# <a href="/title/tt0253474/" title="Roman Polanski (dir.), Adrien Brody, Thomas Kretschmann">El pianista</a>
# <strong title="8.5 based on 826,613 user ratings">8.5</strong>
# <div class="seen-widget seen-widget-tt0253474 pending" data-titleid="tt0253474">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0253474"></div>
# <span data-value="34" name="rk"></span>
# <a href="/title/tt6751668/" title="Bong Joon Ho (dir.), Song Kang-ho, Lee Sun-kyun">Parásitos</a>
# <strong title="8.5 based on 789,049 user ratings">8.5</strong>
# <div class="seen-widget seen-widget-tt6751668 pending" data-titleid="tt6751668">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt6751668"></div>
# <span data-value="35" name="rk"></span>
# <a href="/title/tt0110413/" title="Luc Besson (dir.), Jean Reno, Gary Oldman">El profesional (Léon)</a>
# <strong title="8.5 based on 1,153,957 user ratings">8.5</strong>
# <div class="seen-widget seen-widget-tt0110413 pending" data-titleid="tt0110413">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0110413"></div>
# <span data-value="36" name="rk"></span>
# <a href="/title/tt0110357/" title="Roger Allers (dir.), Matthew Broderick, Jeremy Irons">El rey león</a>
# <strong title="8.5 based on 1,051,447 user ratings">8.5</strong>
# <div class="seen-widget seen-widget-tt0110357 pending" data-titleid="tt0110357">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0110357"></div>
# <span data-value="37" name="rk"></span>
# <a href="/title/tt0172495/" title="Ridley Scott (dir.), Russell Crowe, Joaquin Phoenix">Gladiator (El gladiador)</a>
# <strong title="8.5 based on 1,490,317 user ratings">8.5</strong>
# <div class="seen-widget seen-widget-tt0172495 pending" data-titleid="tt0172495">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0172495"></div>
# <span data-value="38" name="rk"></span>
# <a href="/title/tt0120586/" title="Tony Kaye (dir.), Edward Norton, Edward Furlong">American History X</a>
# <strong title="8.5 based on 1,117,465 user ratings">8.5</strong>
# <div class="seen-widget seen-widget-tt0120586 pending" data-titleid="tt0120586">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0120586"></div>
# <span data-value="39" name="rk"></span>
# <a href="/title/tt0407887/" title="Martin Scorsese (dir.), Leonardo DiCaprio, Matt Damon">Infiltrados</a>
# <strong title="8.5 based on 1,316,937 user ratings">8.5</strong>
# <div class="seen-widget seen-widget-tt0407887 pending" data-titleid="tt0407887">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0407887"></div>
# <span data-value="40" name="rk"></span>
# <a href="/title/tt0114814/" title="Bryan Singer (dir.), Kevin Spacey, Gabriel Byrne">Sospechosos habituales</a>
# <strong title="8.5 based on 1,080,349 user ratings">8.5</strong>
# <div class="seen-widget seen-widget-tt0114814 pending" data-titleid="tt0114814">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0114814"></div>
# <span data-value="41" name="rk"></span>
# <a href="/title/tt0482571/" title="Christopher Nolan (dir.), Christian Bale, Hugh Jackman">El truco final (El prestigio)</a>
# <strong title="8.5 based on 1,324,720 user ratings">8.5</strong>
# <div class="seen-widget seen-widget-tt0482571 pending" data-titleid="tt0482571">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0482571"></div>
# <span data-value="42" name="rk"></span>
# <a href="/title/tt2582802/" title="Damien Chazelle (dir.), Miles Teller, J.K. Simmons">Whiplash</a>
# <strong title="8.5 based on 849,570 user ratings">8.5</strong>
# <div class="seen-widget seen-widget-tt2582802 pending" data-titleid="tt2582802">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt2582802"></div>
# <span data-value="43" name="rk"></span>
# <a href="/title/tt0034583/" title="Michael Curtiz (dir.), Humphrey Bogart, Ingrid Bergman">Casablanca</a>
# <strong title="8.5 based on 569,882 user ratings">8.5</strong>
# <div class="seen-widget seen-widget-tt0034583 pending" data-titleid="tt0034583">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0034583"></div>
# <span data-value="44" name="rk"></span>
# <a href="/title/tt1675434/" title="Olivier Nakache (dir.), François Cluzet, Omar Sy">Intocable</a>
# <strong title="8.5 based on 852,652 user ratings">8.5</strong>
# <div class="seen-widget seen-widget-tt1675434 pending" data-titleid="tt1675434">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt1675434"></div>
# <span data-value="45" name="rk"></span>
# <a href="/title/tt0056058/" title="Masaki Kobayashi (dir.), Tatsuya Nakadai, Akira Ishihama">Harakiri</a>
# <strong title="8.5 based on 57,075 user ratings">8.5</strong>
# <div class="seen-widget seen-widget-tt0056058 pending" data-titleid="tt0056058">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0056058"></div>
# <span data-value="46" name="rk"></span>
# <a href="/title/tt0095327/" title="Isao Takahata (dir.), Tsutomu Tatsumi, Ayano Shiraishi">La tumba de las luciérnagas</a>
# <strong title="8.5 based on 276,099 user ratings">8.5</strong>
# <div class="seen-widget seen-widget-tt0095327 pending" data-titleid="tt0095327">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0095327"></div>
# <span data-value="47" name="rk"></span>
# <a href="/title/tt0027977/" title="Charles Chaplin (dir.), Charles Chaplin, Paulette Goddard">Tiempos modernos</a>
# <strong title="8.4 based on 242,273 user ratings">8.4</strong>
# <div class="seen-widget seen-widget-tt0027977 pending" data-titleid="tt0027977">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0027977"></div>
# <span data-value="48" name="rk"></span>
# <a href="/title/tt0064116/" title="Sergio Leone (dir.), Henry Fonda, Charles Bronson">Hasta que llegó su hora</a>
# <strong title="8.4 based on 328,823 user ratings">8.4</strong>
# <div class="seen-widget seen-widget-tt0064116 pending" data-titleid="tt0064116">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0064116"></div>
# <span data-value="49" name="rk"></span>
# <a href="/title/tt0047396/" title="Alfred Hitchcock (dir.), James Stewart, Grace Kelly">La ventana indiscreta</a>
# <strong title="8.4 based on 490,462 user ratings">8.4</strong>
# <div class="seen-widget seen-widget-tt0047396 pending" data-titleid="tt0047396">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0047396"></div>
# <span data-value="50" name="rk"></span>
# <a href="/title/tt0078748/" title="Ridley Scott (dir.), Sigourney Weaver, Tom Skerritt">Alien, el octavo pasajero</a>
# <strong title="8.4 based on 877,684 user ratings">8.4</strong>
# <div class="seen-widget seen-widget-tt0078748 pending" data-titleid="tt0078748">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0078748"></div>
# <span data-value="51" name="rk"></span>
# <a href="/title/tt0021749/" title="Charles Chaplin (dir.), Charles Chaplin, Virginia Cherrill">Luces de la ciudad</a>
# <strong title="8.4 based on 184,800 user ratings">8.4</strong>
# <div class="seen-widget seen-widget-tt0021749 pending" data-titleid="tt0021749">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0021749"></div>
# <span data-value="52" name="rk"></span>
# <a href="/title/tt0095765/" title="Giuseppe Tornatore (dir.), Philippe Noiret, Enzo Cannavale">Cinema Paradiso</a>
# <strong title="8.4 based on 260,651 user ratings">8.4</strong>
# <div class="seen-widget seen-widget-tt0095765 pending" data-titleid="tt0095765">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0095765"></div>
# <span data-value="53" name="rk"></span>
# <a href="/title/tt0078788/" title="Francis Ford Coppola (dir.), Martin Sheen, Marlon Brando">Apocalypse Now</a>
# <strong title="8.4 based on 664,907 user ratings">8.4</strong>
# <div class="seen-widget seen-widget-tt0078788 pending" data-titleid="tt0078788">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0078788"></div>
# <span data-value="54" name="rk"></span>
# <a href="/title/tt0209144/" title="Christopher Nolan (dir.), Guy Pearce, Carrie-Anne Moss">Memento</a>
# <strong title="8.4 based on 1,231,914 user ratings">8.4</strong>
# <div class="seen-widget seen-widget-tt0209144 pending" data-titleid="tt0209144">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0209144"></div>
# <span data-value="55" name="rk"></span>
# <a href="/title/tt0082971/" title="Steven Spielberg (dir.), Harrison Ford, Karen Allen">En busca del arca perdida</a>
# <strong title="8.4 based on 961,454 user ratings">8.4</strong>
# <div class="seen-widget seen-widget-tt0082971 pending" data-titleid="tt0082971">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0082971"></div>
# <span data-value="56" name="rk"></span>
# <a href="/title/tt1853728/" title="Quentin Tarantino (dir.), Jamie Foxx, Christoph Waltz">Django desencadenado</a>
# <strong title="8.4 based on 1,540,239 user ratings">8.4</strong>
# <div class="seen-widget seen-widget-tt1853728 pending" data-titleid="tt1853728">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt1853728"></div>
# <span data-value="57" name="rk"></span>
# <a href="/title/tt0910970/" title="Andrew Stanton (dir.), Ben Burtt, Elissa Knight">WALL·E</a>
# <strong title="8.4 based on 1,109,783 user ratings">8.4</strong>
# <div class="seen-widget seen-widget-tt0910970 pending" data-titleid="tt0910970">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0910970"></div>
# <span data-value="58" name="rk"></span>
# <a href="/title/tt0405094/" title="Florian Henckel von Donnersmarck (dir.), Ulrich Mühe, Martina Gedeck">La vida de los otros</a>
# <strong title="8.4 based on 389,218 user ratings">8.4</strong>
# <div class="seen-widget seen-widget-tt0405094 pending" data-titleid="tt0405094">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0405094"></div>
# <span data-value="59" name="rk"></span>
# <a href="/title/tt0043014/" title="Billy Wilder (dir.), William Holden, Gloria Swanson">El crepúsculo de los dioses</a>
# <strong title="8.4 based on 221,970 user ratings">8.4</strong>
# <div class="seen-widget seen-widget-tt0043014 pending" data-titleid="tt0043014">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0043014"></div>
# <span data-value="60" name="rk"></span>
# <a href="/title/tt0050825/" title="Stanley Kubrick (dir.), Kirk Douglas, Ralph Meeker">Senderos de gloria</a>
# <strong title="8.4 based on 197,475 user ratings">8.4</strong>
# <div class="seen-widget seen-widget-tt0050825 pending" data-titleid="tt0050825">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0050825"></div>
# <span data-value="61" name="rk"></span>
# <a href="/title/tt0032553/" title="Charles Chaplin (dir.), Charles Chaplin, Paulette Goddard">El gran dictador</a>
# <strong title="8.4 based on 223,976 user ratings">8.4</strong>
# <div class="seen-widget seen-widget-tt0032553 pending" data-titleid="tt0032553">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0032553"></div>
# <span data-value="62" name="rk"></span>
# <a href="/title/tt0081505/" title="Stanley Kubrick (dir.), Jack Nicholson, Shelley Duvall">El resplandor</a>
# <strong title="8.4 based on 1,015,463 user ratings">8.4</strong>
# <div class="seen-widget seen-widget-tt0081505 pending" data-titleid="tt0081505">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0081505"></div>
# <span data-value="63" name="rk"></span>
# <a href="/title/tt4154756/" title="Anthony Russo (dir.), Robert Downey Jr., Chris Hemsworth">Vengadores: Infinity War</a>
# ...
# <strong title="8.0 based on 37,706 user ratings">8.0</strong>
# <div class="seen-widget seen-widget-tt0035446 pending" data-titleid="tt0035446">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0035446"></div>
# <span data-value="231" name="rk"></span>
# <a href="/title/tt0058946/" title="Gillo Pontecorvo (dir.), Brahim Hadjadj, Jean Martin">La batalla de Argel</a>
# <strong title="8.0 based on 60,542 user ratings">8.0</strong>
# <div class="seen-widget seen-widget-tt0058946 pending" data-titleid="tt0058946">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0058946"></div>
# <span data-value="232" name="rk"></span>
# <a href="/title/tt1028532/" title="Lasse Hallström (dir.), Richard Gere, Joan Allen">Siempre a tu lado (Hachiko)</a>
# <strong title="8.0 based on 284,809 user ratings">8.0</strong>
# <div class="seen-widget seen-widget-tt1028532 pending" data-titleid="tt1028532">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt1028532"></div>
# <span data-value="233" name="rk"></span>
# <a href="/title/tt0032551/" title="John Ford (dir.), Henry Fonda, Jane Darwell">Las uvas de la ira</a>
# <strong title="8.0 based on 93,658 user ratings">8.0</strong>
# <div class="seen-widget seen-widget-tt0032551 pending" data-titleid="tt0032551">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0032551"></div>
# <span data-value="234" name="rk"></span>
# <a href="/title/tt0325980/" title="Gore Verbinski (dir.), Johnny Depp, Geoffrey Rush">Piratas del Caribe: La maldición de la Perla Negra</a>
# <strong title="8.0 based on 1,122,014 user ratings">8.0</strong>
# <div class="seen-widget seen-widget-tt0325980 pending" data-titleid="tt0325980">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0325980"></div>
# <span data-value="235" name="rk"></span>
# <a href="/title/tt0245712/" title="Alejandro G. Iñárritu (dir.), Emilio Echevarría, Gael García Bernal">Amores perros</a>
# <strong title="8.0 based on 240,823 user ratings">8.0</strong>
# <div class="seen-widget seen-widget-tt0245712 pending" data-titleid="tt0245712">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0245712"></div>
# <span data-value="236" name="rk"></span>
# <a href="/title/tt0476735/" title="Çagan Irmak (dir.), Çetin Tekindor, Fikret Kuskan">Mi padre y mi hijo</a>
# <strong title="8.0 based on 86,981 user ratings">8.0</strong>
# <div class="seen-widget seen-widget-tt0476735 pending" data-titleid="tt0476735">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0476735"></div>
# <span data-value="237" name="rk"></span>
# <a href="/title/tt0032976/" title="Alfred Hitchcock (dir.), Laurence Olivier, Joan Fontaine">Rebeca</a>
# <strong title="8.0 based on 137,685 user ratings">8.0</strong>
# <div class="seen-widget seen-widget-tt0032976 pending" data-titleid="tt0032976">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0032976"></div>
# <span data-value="238" name="rk"></span>
# <a href="/title/tt0113247/" title="Mathieu Kassovitz (dir.), Vincent Cassel, Hubert Koundé">El odio</a>
# <strong title="8.0 based on 173,804 user ratings">8.0</strong>
# <div class="seen-widget seen-widget-tt0113247 pending" data-titleid="tt0113247">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0113247"></div>
# <span data-value="239" name="rk"></span>
# <a href="/title/tt0061512/" title="Stuart Rosenberg (dir.), Paul Newman, George Kennedy">La leyenda del indomable</a>
# <strong title="8.0 based on 177,695 user ratings">8.0</strong>
# <div class="seen-widget seen-widget-tt0061512 pending" data-titleid="tt0061512">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0061512"></div>
# <span data-value="240" name="rk"></span>
# <a href="/title/tt0053198/" title="François Truffaut (dir.), Jean-Pierre Léaud, Albert Rémy">Los cuatrocientos golpes</a>
# <strong title="8.0 based on 118,343 user ratings">8.0</strong>
# <div class="seen-widget seen-widget-tt0053198 pending" data-titleid="tt0053198">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0053198"></div>
# <span data-value="241" name="rk"></span>
# <a href="/title/tt4016934/" title="Park Chan-wook (dir.), Kim Min-hee, Ha Jung-woo">La doncella</a>
# <strong title="8.0 based on 146,909 user ratings">8.0</strong>
# <div class="seen-widget seen-widget-tt4016934 pending" data-titleid="tt4016934">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt4016934"></div>
# <span data-value="242" name="rk"></span>
# <a href="/title/tt0025316/" title="Frank Capra (dir.), Clark Gable, Claudette Colbert">Sucedió una noche</a>
# <strong title="8.0 based on 104,387 user ratings">8.0</strong>
# <div class="seen-widget seen-widget-tt0025316 pending" data-titleid="tt0025316">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0025316"></div>
# <span data-value="243" name="rk"></span>
# <a href="/title/tt0060827/" title="Ingmar Bergman (dir.), Bibi Andersson, Liv Ullmann">Persona</a>
# <strong title="8.0 based on 119,074 user ratings">8.0</strong>
# <div class="seen-widget seen-widget-tt0060827 pending" data-titleid="tt0060827">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0060827"></div>
# <span data-value="244" name="rk"></span>
# <a href="/title/tt0059742/" title="Robert Wise (dir.), Julie Andrews, Christopher Plummer">Sonrisas y lágrimas</a>
# <strong title="8.0 based on 234,272 user ratings">8.0</strong>
# <div class="seen-widget seen-widget-tt0059742 pending" data-titleid="tt0059742">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0059742"></div>
# <span data-value="245" name="rk"></span>
# <a href="/title/tt0079470/" title="Terry Jones (dir.), Graham Chapman, John Cleese">La vida de Brian</a>
# <strong title="8.0 based on 399,652 user ratings">8.0</strong>
# <div class="seen-widget seen-widget-tt0079470 pending" data-titleid="tt0079470">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0079470"></div>
# <span data-value="246" name="rk"></span>
# <a href="/title/tt0071411/" title="Akira Kurosawa (dir.), Maksim Munzuk, Yuriy Solomin">Dersu Uzala (El cazador)</a>
# <strong title="8.0 based on 29,966 user ratings">8.0</strong>
# <div class="seen-widget seen-widget-tt0071411 pending" data-titleid="tt0071411">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0071411"></div>
# <span data-value="247" name="rk"></span>
# <a href="/title/tt0103639/" title="Ron Clements (dir.), Scott Weinger, Robin Williams">Aladdín</a>
# <strong title="8.0 based on 418,498 user ratings">8.0</strong>
# <div class="seen-widget seen-widget-tt0103639 pending" data-titleid="tt0103639">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0103639"></div>
# <span data-value="248" name="rk"></span>
# <a href="/title/tt1454029/" title="Tate Taylor (dir.), Viola Davis, Emma Stone">Criadas y señoras</a>
# <strong title="8.0 based on 458,763 user ratings">8.0</strong>
# <div class="seen-widget seen-widget-tt1454029 pending" data-titleid="tt1454029">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt1454029"></div>
# <span data-value="249" name="rk"></span>
# <a href="/title/tt0083987/" title="Richard Attenborough (dir.), Ben Kingsley, John Gielgud">Gandhi</a>
# <strong title="8.0 based on 231,980 user ratings">8.0</strong>
# <div class="seen-widget seen-widget-tt0083987 pending" data-titleid="tt0083987">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0083987"></div>
# <span data-value="250" name="rk"></span>
# <a href="/title/tt0129167/" title="Brad Bird (dir.), Eli Marienthal, Harry Connick Jr.">El gigante de hierro</a>
# <strong title="8.0 based on 197,611 user ratings">8.0</strong>
# <div class="seen-widget seen-widget-tt0129167 pending" data-titleid="tt0129167">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0129167"></div>

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
#your code

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#your code
